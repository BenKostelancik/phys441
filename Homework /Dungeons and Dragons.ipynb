# %%
import random

import matplotlib.pyplot as plt


def roll(num_sides, num_rolls):
    dict = {}
    for i in range(1, num_sides+1):
        dict[i] = 0
    for i in range(0, num_rolls):
        num = random.randint(1,num_sides)
        dict[num] += 1
    print(dict)
    
    x_values = list(dict.keys())
    y_values = list(dict.values())
    plt.bar(x_values, y_values, width=1, align='center', color='blue', edgecolor='black')
    plt.xticks(x_values)
    plt.xlabel('Sides')
    plt.ylabel('Roll Count')
    plt.title('Histogram of role count for sides of die')
    plt.show()

roll(20, 1000000)
# Out:
# {1: 50338, 2: 50060, 3: 50092, 4: 49748, 5: 50209, 6: 50125, 7: 49734, 8: 50173, 9: 50147, 10: 49789, 11: 49953, 12: 49801, 13: 49766, 14: 49757, 15: 49777, 16: 49882, 17: 50233, 18: 50124, 19: 50102, 20: 50190}

# %%
def max_num(n,m):
    l = []
    for i in range(0,m):
        num = random.randint(1,n)
        l.append(num)
        
    return max(l)

# %%
d = {}
dict = {}
for i in range(1, 21):
    dict[i] = 0
        
for i in range(0,1000000):
    num = max_num(20,2)
    dict[num] += 1

x_values = list(dict.keys())
y_values = list(dict.values())
plt.bar(x_values, y_values, width=1, align='center', color='blue', edgecolor='black')
plt.xticks(x_values)
plt.xlabel('Sides')
plt.ylabel('Roll Count')
plt.title('Histogram of role count for sides of die')
plt.show()

# %%
#The shape is a staircase which is pretty cool!
